# %% [markdown]
# # Bonus (Julia)
#
# This notebook sets up experiments to compare axis choices for odd/even blocks.

# %%
include("julia_utils.jl")
using LinearAlgebra
phi = random_phi(seed=101)

# %%
cases = 1:9
max_layers = 4

# %% [markdown]
# ## Evaluation scaffold
#
# When `objective_case` is fully implemented, evaluate each case/layer and plot the minimum distance ε as in the Python bonus study.

# %%
# Placeholder container for future results
epsilons = Dict(case => Float64[] for case in cases)
for case in cases
    for L in 1:max_layers
        # TODO: perform optimization and push! minimal epsilon for (case, L)
    end
end
epsilons
